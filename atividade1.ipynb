# %% [markdown]
# # Predição de Despesas Médicas do Seguro de Saúde

# %% [markdown]
# Este conjunto de dados *insurance.csv* representa despesas médicas de indivíduos nos EUA.<br/>
# Predizer despesas médicas é de fundamental importância para uma empresa de seguros de saúde. É tambem de interesse de cada pessoa.

# %% [markdown]
# #### Vamos realizar uma analise exploratória dos dados (EDA) utilizado o Seaborn

# %% [markdown]
# - age: idade do beneficiário primário.
# - sex: empreiteiro de seguros gênero feminino, masculino.
# - bmi: Índice de massa corporal (IMC),  a relação entre altura e peso é dada por (kg / m ^ 2), idealmente o valor deve ficar entre 18,5 a 24,9.
# - children: Número de dependentes / Número de crianças cobertas pelo seguro de saúde.
# - smoker: A pessoa é fumante ou não.
# - region: a área residencial do beneficiário nos EUA, nordeste, sudeste, sudoeste e noroeste.
# - expenses: custos médicos individuais faturados pelo seguro de saúde.

# %% [markdown]
# ###Importe as bibliotecas que vamos precisar para gerar nossos gráficos, tabelas e insights

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ###Carregue/Leia o DataFrame

# %%
df = pd.read_csv('https://raw.githubusercontent.com/amandaacacio/Diabetes-Classification/main/insurance.csv')

# %% [markdown]
# ###Mostre na tela as primeiras cinco linhas do dataframe

# %%
df.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %% [markdown]
# ###Mostre na tela as informações gerais do dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   expenses  1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %% [markdown]
# ###Mostre na tela um resumo estatístico dos dados numéricos

# %%
df.describe()
# Out:
#                age          bmi     children      expenses
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.665471     1.094918  13270.422414
# std      14.049960     6.098382     1.205493  12110.011240
# min      18.000000    16.000000     0.000000   1121.870000
# 25%      27.000000    26.300000     0.000000   4740.287500
# 50%      39.000000    30.400000     1.000000   9382.030000
# 75%      51.000000    34.700000     2.000000  16639.915000
# max      64.000000    53.100000     5.000000  63770.430000

# %% [markdown]
# ### Qual o número de fumantes e não fumantes? Se preferir, plote esses números num gráfico

# %%
count = df['smoker'].value_counts()

# Plotar os números em um gráfico de barras
count.plot(kind='bar', color=['blue', 'orange'])
plt.title('Número de fumantes e não fumantes')
plt.xlabel('Fumante')
plt.ylabel('Quantidade')
plt.show()

print(count)
# Out:
# smoker
# no     1064
# yes     274
# Name: count, dtype: int64

# %% [markdown]
# ### Há mais homens ou mulheres?

# %%
count = df['sex'].value_counts()

# Plotar os números em um gráfico de barras
count.plot(kind='bar', color=['blue', 'orange'])
plt.title('Número de homens e mulheres')
plt.xlabel('Sexo')
plt.ylabel('Quantidade')
plt.show()

print(count)
# Out:
# sex
# male      676
# female    662
# Name: count, dtype: int64

# %% [markdown]
# ### E se fizermos distinção de gênero considerando os fumantes? Haverá mais homens que fumam ou mulheres fumantes?

# %%
plt.figure(figsize=(7,10))
sns.countplot(x='sex', hue='smoker', data=df)
plt.title('Número de homens e mulheres fumantes')
plt.show()

# %% [markdown]
# ### Como os dados da idade se distribuem? E os gastos?

# %%
count = df['age'].value_counts()

# Plotar os números em um gráfico de barras
plt.figure(figsize=(7,10))
count.plot(kind='bar', color=['blue', 'orange'])
plt.title('Distribuição de idade')
plt.xlabel('Idade')
plt.ylabel('Quantidade')
plt.show()

print(count)
# Out:
# age
# 18    69
# 19    68
# 50    29
# 51    29
# 47    29
# 46    29
# 45    29
# 20    29
# 48    29
# 52    29
# 22    28
# 49    28
# 54    28
# 53    28
# 21    28
# 26    28
# 24    28
# 25    28
# 28    28
# 27    28
# 23    28
# 43    27
# 29    27
# 30    27
# 41    27
# 42    27
# 44    27
# 31    27
# 40    27
# 32    26
# 33    26
# 56    26
# 34    26
# 55    26
# 57    26
# 37    25
# 59    25
# 58    25
# 36    25
# 38    25
# 35    25
# 39    25
# 61    23
# 60    23
# 63    23
# 62    23
# 64    22
# Name: count, dtype: int64

# %%
media_gastos_por_idade = df.groupby('age')['expenses'].mean()
print(media_gastos_por_idade)
# Out:
# age
# 18     7086.217971
# 19     9747.909706
# 20    10159.697931
# 21     4730.464286
# 22    10012.932857
# 23    12419.820357
# 24    10648.015714
# 25     9838.365000
# 26     6133.825714
# 27    12184.701429
# 28     9069.187500
# 29    10430.159630
# 30    12719.111111
# 31    10196.980000
# 32     9220.299615
# 33    12351.532308
# 34    11613.528462
# 35    11307.183200
# 36    12204.477600
# 37    18019.911600
# 38     8102.732800
# 39    11778.243600
# 40    11772.251481
# 41     9653.745556
# 42    13061.038519
# 43    19267.279630
# 44    15859.397037
# 45    14830.199310
# 46    14342.591379
# 47    17653.999655
# 48    14632.500000
# 49    12696.006071
# 50    15663.003103
# 51    15682.255517
# 52    18256.270345
# 53    16020.930357
# 54    18758.546429
# 55    16164.545000
# 56    15025.517692
# 57    16447.186154
# 58    13878.928000
# 59    18895.869600
# 60    21979.419130
# 61    22024.457391
# 62    19163.856087
# 63    19884.999130
# 64    23275.530909
# Name: expenses, dtype: float64

# %% [markdown]
# ### Quem gasta mais com o plano de saúde? Fumantes ou não fumantes?

# %% [markdown]
# - Valor total

# %%
gastos_por_fumante = df.groupby('smoker')['expenses'].sum()
print(gastos_por_fumante)
# Out:
# smoker
# no     8974061.63
# yes    8781763.56
# Name: expenses, dtype: float64

# %% [markdown]
# - Valor médio

# %%
media_gastos_por_fumante = df.groupby('smoker')['expenses'].mean()
print(media_gastos_por_fumante)
# Out:
# smoker
# no      8434.268449
# yes    32050.231971
# Name: expenses, dtype: float64

# %% [markdown]
# ### Vamos verificar a correlação dos dados

# %%
correlacao = gastos_por_fumante.corr(media_gastos_por_fumante)

print("Correlação entre valor total e médio dos gastos:", correlacao)
# Out:
# Correlação entre valor total e médio dos gastos: 1.0

# %% [markdown]
# ###Utilize o pairplot para uma visualização diferente. Se preferir, filtre as variáveis que prefere ver a correlação, o pairplot pode demorar para rodar com todas as variáveis juntas.

# %%
# Calculando o valor total e médio dos gastos por categoria de fumante
gastos_agrupados = df.groupby('smoker')['expenses'].agg(['sum', 'mean'])

# Resetando o índice para manter 'fumante' como uma coluna
gastos_agrupados.reset_index(inplace=True)

# Renomeando as colunas
gastos_agrupados.columns = ['Fumante', 'Gastos Totais', 'Gastos Médios']

# Filtrando apenas as variáveis de interesse para o pairplot
cols_interesse = ['Gastos Totais', 'Gastos Médios']
dados_para_plot = gastos_agrupados[cols_interesse]

sns.pairplot(dados_para_plot)

# Exibindo o gráfico
plt.show()

# %% [markdown]
# ### Qual a relação dos gastos com o IMC fazendo distinção dos fumantes?

# %%
sns.scatterplot(data=df, x='bmi', y='expenses', hue='smoker')
plt.xlabel('IMC')
plt.ylabel('Gastos com plano de saúde')
plt.title('Relação entre gastos e IMC (distinção entre fumantes)')
plt.legend(title='Fumante', loc='upper right')
plt.show()

# %% [markdown]
# ### Referência

# %% [markdown]
# - https://seaborn.pydata.org/examples/index.html
